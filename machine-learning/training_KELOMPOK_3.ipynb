# %%
# ============================================
# INSTALL KAGGLE
# ============================================

# !pip install -q kaggle


# ============================================
# BUAT kaggle.json OTOMATIS
# ============================================

import os
import json

kaggle_info = {
    "username": "domainaku",
    "key": "KGAT_318be669ca4e1b0c3b9ff66cf3872fff"
}

os.makedirs("/root/.kaggle", exist_ok=True)

with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump(kaggle_info, f)

os.chmod("/root/.kaggle/kaggle.json", 600)

print("Kaggle API berhasil dikonfigurasi!")


# ============================================
# DOWNLOAD DATASET
# ============================================

# !kaggle datasets download -d techsash/waste-classification-data


# ============================================
# EXTRACT DATASET
# ============================================

import zipfile

zip_path = "/content/waste-classification-data.zip"
extract_path = "/content/DATASET"

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Dataset berhasil diekstrak!")


# ============================================
# CEK ISI DATASET
# ============================================

import os

print(os.listdir("/content/DATASET"))


# ============================================
# EDA - HITUNG JUMLAH DATA
# ============================================

import matplotlib.pyplot as plt

dataset_path = "/content/DATASET/TRAIN"

organic_count = len(os.listdir(os.path.join(dataset_path, "O")))
recyclable_count = len(os.listdir(os.path.join(dataset_path, "R")))

print("Jumlah Dataset:")
print(f"Organic     : {organic_count}")
print(f"Recyclable  : {recyclable_count}")


# ============================================
# VISUALISASI GRAFIK
# ============================================

classes = ["Organic", "Recyclable"]
counts = [organic_count, recyclable_count]

plt.figure(figsize=(6,4))

bars = plt.bar(classes, counts)

plt.title("Jumlah Data per Kelas")
plt.xlabel("Class")
plt.ylabel("Jumlah Gambar")

for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        yval + 50,
        int(yval),
        ha='center'
    )

plt.show()

# %%
import os

print(os.listdir("/content/DATASET/dataset/DATASET"))
# Out:
# ['TRAIN', 'TEST']

# %%
import os
import matplotlib.pyplot as plt

# PATH FINAL
dataset_path = "/content/DATASET/dataset/DATASET/TRAIN"

# Hitung jumlah data
organic_count = len(os.listdir(os.path.join(dataset_path, "O")))
recyclable_count = len(os.listdir(os.path.join(dataset_path, "R")))

# Print jumlah
print("Jumlah Dataset:")
print(f"Organic     : {organic_count}")
print(f"Recyclable  : {recyclable_count}")

# Grafik
classes = ["Organic", "Recyclable"]
counts = [organic_count, recyclable_count]

plt.figure(figsize=(6,4))

bars = plt.bar(classes, counts)

plt.title("Jumlah Data per Kelas")
plt.xlabel("Class")
plt.ylabel("Jumlah Gambar")

for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,
        yval + 50,
        int(yval),
        ha='center'
    )

plt.show()
# Out:
# Jumlah Dataset:
# Organic     : 12565
# Recyclable  : 9999
